# %%
#import in necessary libraries
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.dates as mdates
import datetime as dt
import os
df = pd.read_csv("Suicidal Behaviors among Adolescent.csv")
df
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0             Argentina  2018     13-15  Female                     50.3
# 1             Argentina  2018     13-15    Male                     44.9
# 2             Argentina  2018     16-17  Female                     67.2
# 3             Argentina  2018     16-17    Male                     68.1
# 4             Argentina  2012     13-15    Male                     49.3
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Have_Understanding_Parents  \
# ...

# %%
df.head(3)
# Out:
#      Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 0  Argentina  2018     13-15  Female                     50.3
# 1  Argentina  2018     13-15    Male                     44.9
# 2  Argentina  2018     16-17  Female                     67.2
#
#    Really_Get_Drunk  Overwieght  Use_Marijuana  Have_Understanding_Parents  \
# 0              30.7        27.8            7.9                        41.5
# 1              26.1        39.1            8.4                        44.5
# 2              56.3        22.5           21.9                        37.1
#
#    Missed_classes_without_permssion  Had_sexual_relation  Smoke_cig_currently  \
# 0                              24.7                 25.7                 16.8
# 1                              27.9                 38.4                 12.1
# 2                              34.0                 59.1                 28.5
#
#    Had_fights  Bullied  Got_Seriously_injured  No_close_friends  \
# ...

# %%
df.tail(3)
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Have_Understanding_Parents  \
# 103              27.1        63.0            2.0                        36.3
# 104              53.7        57.8           10.1                        36.5
# 105              51.7        70.6            3.9                        37.8
#
#      Missed_classes_without_permssion  Had_sexual_relation  \
# 103                              16.2                 13.6
# 104                              38.9                 55.7
# 105                              37.2                 22.4
#
#      Smoke_cig_currently  Had_fights  Bullied  Got_Seriously_injured  \
# ...

# %%
df.loc[0, "Country"]
# Out:
# 'Argentina'

# %%
#shape
df.shape
# Out:
# (106, 17)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Age Group', 'Sex', 'Currently_Drink_Alcohol',
#        'Really_Get_Drunk', 'Overwieght', 'Use_Marijuana',
#        'Have_Understanding_Parents', 'Missed_classes_without_permssion',
#        'Had_sexual_relation', 'Smoke_cig_currently', 'Had_fights', 'Bullied',
#        'Got_Seriously_injured', 'No_close_friends', 'Attempted_suicide'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           106 non-null    object
#  1   Year                              106 non-null    int64
#  2   Age Group                         106 non-null    object
#  3   Sex                               106 non-null    object
#  4   Currently_Drink_Alcohol           106 non-null    float64
#  5   Really_Get_Drunk                  106 non-null    float64
#  6   Overwieght                        106 non-null    float64
#  7   Use_Marijuana                     106 non-null    float64
#  8   Have_Understanding_Parents        106 non-null    float64
#  9   Missed_classes_without_permssion  106 non-null    float64
#  10  Had_sexual_relation               106 non-null    float64
# ...

# %%
#dropping some null values
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 4 to 105
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           100 non-null    object
#  1   Year                              100 non-null    int64
#  2   Age Group                         100 non-null    object
#  3   Sex                               100 non-null    object
#  4   Currently_Drink_Alcohol           100 non-null    float64
#  5   Really_Get_Drunk                  100 non-null    float64
#  6   Overwieght                        100 non-null    float64
#  7   Use_Marijuana                     100 non-null    float64
#  8   Have_Understanding_Parents        100 non-null    float64
#  9   Missed_classes_without_permssion  100 non-null    float64
#  10  Had_sexual_relation               100 non-null    float64
# ...

# %%
df["Country"].nunique()
# Out:
# 26

# %%
df["Country"].values
# Out:
# array(['Argentina', 'Argentina', 'Benin', 'Benin', 'Benin', 'Benin',
#        'Bhutan', 'Bhutan', 'Bhutan', 'Bhutan', 'Brunei Darussalam ',
#        'Brunei Darussalam ', 'Brunei Darussalam ', 'Brunei Darussalam ',
#        'Dominican Republic ', 'Dominican Republic ',
#        'Dominican Republic ', 'Dominican Republic ', 'Fiji Islands',
#        'Fiji Islands', 'Fiji Islands', 'Fiji Islands', 'Indonesia',
#        'Indonesia', 'Indonesia', 'Indonesia', 'Jamaica', 'Jamaica',
#        'Jamaica', 'Jamaica', 'Kiribati', 'Kiribati', 'Laos', 'Laos',
#        'Laos', 'Laos', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia',
#        'Mauritus', 'Mauritus', 'Mauritus', 'Mauritus', 'Mongolia',
#        'Mongolia', 'Mongolia', 'Mongolia', 'Mongolia', 'Mongolia',
#        'Namibia', 'Namibia', 'Namibia', 'Namibia', 'Nepal', 'Nepal',
#        'Nepal', 'Nepal', 'Peru', 'Peru', 'Samoa', 'Samoa', 'Samoa',
#        'Samoa', 'Samoa', 'Samoa', 'Seychelles', 'Seychelles',
# ...

# %%
df["Age Group"]
# Out:
# 4      13-15
# 5      13-15
# 8      13-15
# 9      13-15
# 10     16-17
#        ...
# 101    13-15
# 102    13-15
# 103    13-15
# 104    16-17
# 105    16-17
# Name: Age Group, Length: 100, dtype: object

# %%
#done over 8 years
df["Year"].nunique()
# Out:
# 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 4 to 105
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           100 non-null    object
#  1   Year                              100 non-null    int64
#  2   Age Group                         100 non-null    object
#  3   Sex                               100 non-null    object
#  4   Currently_Drink_Alcohol           100 non-null    float64
#  5   Really_Get_Drunk                  100 non-null    float64
#  6   Overwieght                        100 non-null    float64
#  7   Use_Marijuana                     100 non-null    float64
#  8   Have_Understanding_Parents        100 non-null    float64
#  9   Missed_classes_without_permssion  100 non-null    float64
#  10  Had_sexual_relation               100 non-null    float64
# ...

# %%
#statistics
df.describe()
# Out:
#               Year  Currently_Drink_Alcohol  Really_Get_Drunk  Overwieght  \
# count   100.000000                100.00000        100.000000  100.000000
# mean   2014.640000                 30.85900         20.575000   23.229000
# std       1.977244                 54.75516         14.091694   16.045008
# min    2010.000000                  1.40000          0.800000    3.300000
# 25%    2013.000000                 10.22500          8.350000   11.275000
# 50%    2015.000000                 23.80000         18.200000   21.000000
# 75%    2016.000000                 40.60000         29.050000   30.200000
# max    2017.000000                548.00000         55.300000   70.600000
#
#        Use_Marijuana  Have_Understanding_Parents  \
# count     100.000000                  100.000000
# mean        7.219000                   32.624000
# std         8.594251                   11.627641
# min         0.000000                    5.600000
# 25%         1.900000                   25.300000
# ...

# %%
#common countries
df["Country"].mode()
# Out:
# 0    Mongolia
# 1       Samoa
# 2    Vanuatu
# Name: Country, dtype: object

# %%
#common Age group
df["Age Group"].mode()
# Out:
# 0    13-15
# Name: Age Group, dtype: object

# %%
#data correlation
df.corr()
# Out:
#                                       Year  Currently_Drink_Alcohol  \
# Year                              1.000000                 0.171543
# Currently_Drink_Alcohol           0.171543                 1.000000
# Really_Get_Drunk                  0.173470                 0.348566
# Overwieght                        0.100181                 0.034048
# Use_Marijuana                     0.139145                 0.307827
# Have_Understanding_Parents        0.024895                 0.077462
# Missed_classes_without_permssion -0.199816                -0.004900
# Had_sexual_relation               0.155110                 0.411886
# Smoke_cig_currently              -0.039194                 0.128407
# Had_fights                       -0.214888                 0.048052
# Bullied                          -0.263084                -0.028102
# Got_Seriously_injured            -0.089851                -0.000669
# No_close_friends                  0.173593                 0.140255
# ...

# %%
df
# Out:
#                 Country  Year Age Group     Sex  Currently_Drink_Alcohol  \
# 4             Argentina  2012     13-15    Male                     49.3
# 5             Argentina  2012     13-15  Female                     50.7
# 8                 Benin  2016     13-15    Male                     38.0
# 9                 Benin  2016     13-15  Female                     42.4
# 10                Benin  2016     16-17    Male                     46.5
# ..                  ...   ...       ...     ...                      ...
# 101            Vanuatu   2011     13-15  Female                      5.8
# 102  Wallis and Futuna   2015     13-15    Male                     32.2
# 103  Wallis and Futuna   2015     13-15  Female                     24.4
# 104  Wallis and Futuna   2015     16-17    Male                     48.3
# 105  Wallis and Futuna   2015     16-17  Female                     42.9
#
#      Really_Get_Drunk  Overwieght  Use_Marijuana  Have_Understanding_Parents  \
# ...

# %%
#grouping based on Attempted suicide
Drunk = df.groupby(by = ["Country", "Year", "Age Group","Bullied","Really_Get_Drunk", "Use_Marijuana", "Had_sexual_relation", "Smoke_cig_currently", "Attempted_suicide"])["Use_Marijuana"].count().reset_index(name = "count")
Drunk = Drunk.sort_values("Attempted_suicide", ascending = False)
Drunk = Drunk.set_index("Attempted_suicide")
Drunk
# Out:
#                      Country  Year Age Group  Bullied  Really_Get_Drunk  \
# Attempted_suicide
# 67.2                   Samoa  2011     13-15     78.6              47.7
# 53.7                   Samoa  2011     13-15     69.4              25.2
# 31.5                Kiribati  2011     13-15     32.2              10.4
# 30.3                Vanuatu   2016     13-15     60.0              15.1
# 29.9                 Namibia  2013     13-15     47.9              26.7
# ...                      ...   ...       ...      ...               ...
# 3.8                     Laos  2015     16-17      9.9              34.0
# 3.7                Indonesia  2015     16-17     24.0              12.7
# 3.6                  Tuvalu   2013     13-15     15.0               2.9
# 3.6                Indonesia  2015     13-15     19.0               0.8
# 2.7                Indonesia  2015     16-17     13.0               1.1
#
#                    Use_Marijuana  Had_sexual_relation  Smoke_cig_currently  \
# ...

# %%
#grouping based on Bullying 
Fight = df.groupby(by= ["Country","Bullied", "Year", "Age Group","Had_fights", "Got_Seriously_injured", "Attempted_suicide"])["Bullied"].count().reset_index(name= "count")
Fight = Fight.sort_values("Bullied", ascending = False)
Fight = Fight.set_index("Country")
Fight
# Out:
#                       Bullied  Year Age Group  Had_fights  \
# Country
# Samoa                    78.6  2011     13-15        73.3
# Samoa                    69.4  2011     13-15        62.1
# Vanuatu                  68.0  2011     13-15        59.9
# Vanuatu                  66.5  2011     13-15        41.8
# Vanuatu                  60.0  2016     13-15        54.4
# ...                       ...   ...       ...         ...
# Malaysia                 12.0  2012     16-17        16.4
# Laos                     12.0  2015     16-17         3.5
# Trinidad and Tobago      11.9  2017     16-17        17.9
# Laos                     11.3  2015     13-15         8.7
# Laos                      9.9  2015     16-17         6.4
#
#                       Got_Seriously_injured  Attempted_suicide  count
# Country
# Samoa                                  87.7               67.2      1
# Samoa                                  78.6               53.7      1
# ...

# %%
TopSuicide = Drunk.query("`Attempted_suicide` >=30")
TopSuicide
# Out:
#                     Country  Year Age Group  Really_Get_Drunk  Use_Marijuana  \
# Attempted_suicide
# 67.2                  Samoa  2011     13-15              47.7           43.2
# 53.7                  Samoa  2011     13-15              25.2           24.7
# 31.5               Kiribati  2011     13-15              10.4            1.6
# 30.3               Vanuatu   2016     13-15              15.1            5.3
#
#                    Had_sexual_relation  Smoke_cig_currently  count
# Attempted_suicide
# 67.2                              68.5                 42.2      1
# 53.7                              44.9                 25.3      1
# 31.5                               9.8                 19.5      1
# 30.3                              32.3                 21.2      1

# %%
TopBully = Fight.query("`Bullied` >= 60")
TopBully
# Out:
#           Bullied  Year Age Group  Had_fights  Got_Seriously_injured  \
# Country
# Samoa        78.6  2011     13-15        73.3                   87.7
# Samoa        69.4  2011     13-15        62.1                   78.6
# Vanuatu      68.0  2011     13-15        59.9                   66.9
# Vanuatu      66.5  2011     13-15        41.8                   57.4
# Vanuatu      60.0  2016     13-15        54.4                   71.8
#
#           Attempted_suicide  count
# Country
# Samoa                  67.2      1
# Samoa                  53.7      1
# Vanuatu                28.3      1
# Vanuatu                19.5      1
# Vanuatu                30.3      1

# %%
df.plot(kind = "scatter", x = "Really_Get_Drunk",  y ="Attempted_suicide")
plt.title("Drunk and Suicide")
# Out:
# Text(0.5, 1.0, 'Drunk and Suicide')

# %%
df.plot(kind = "scatter", x = "Use_Marijuana", y = "Attempted_suicide", c  ="k")
plt.title("Marijuana vs Suicide")
# Out:
# Text(0.5, 1.0, 'Marijuana vs Suicide')

# %%
df.plot(kind = "scatter", x = "Bullied", y = "Attempted_suicide", c = "r")
plt.title("Bullied vs Suicide")
# Out:
# Text(0.5, 1.0, 'Bullied vs Suicide')

# %%
df.plot(kind = "scatter", x = "Had_sexual_relation", y = "Attempted_suicide", c = "g")
plt.title("Sexual relation vs Suicide")
# Out:
# Text(0.5, 1.0, 'Sexual relation vs Suicide')

# %%
df.plot(kind = "scatter", x = "No_close_friends", y = "Attempted_suicide")
plt.title("No Friends vs Suicide")
# Out:
# Text(0.5, 1.0, 'No Friends vs Suicide')

# %%
sns.barplot(x = TopSuicide.reset_index()["Country"],  y =TopSuicide.reset_index()["Attempted_suicide"])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Attempted_suicide'>
