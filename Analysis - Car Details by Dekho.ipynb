# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv("CARS DATASET.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.shape
# Out:
# (4340, 8)

# %%
#df.axes
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
#checking for null values
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 4335  False  False          False      False  False        False
# 4336  False  False          False      False  False        False
# 4337  False  False          False      False  False        False
# 4338  False  False          False      False  False        False
# 4339  False  False          False      False  False        False
#
#       transmission  owner
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...

# %% [markdown]
# # statistics

# %%
#mean selling price
df["selling_price"].mean()
# Out:
# 504127.3117511521

# %%
#common car name
df["name"].mode()
# Out:
# 0    Maruti Swift Dzire VDI
# Name: name, dtype: object

# %%
#most cars were mmade year:
df["year"].mode()
# Out:
# 0    2017
# Name: year, dtype: int64

# %%
#common fuel:
df["fuel"].mode()
# Out:
# 0    Diesel
# Name: fuel, dtype: object

# %%
#common transmission(manual/automatic)
df["transmission"].mode()
# Out:
# 0    Manual
# Name: transmission, dtype: object

# %%
#cheapest car:
df["selling_price"].min()
# Out:
# 20000

# %%
#most expensive car:
df["selling_price"].max()
# Out:
# 8900000

# %%
#least km driven
df["km_driven"].min()
# Out:
# 1

# %%
#most km driven
df["km_driven"].max()
# Out:
# 806599

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
#correlation
df.corr()
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %% [markdown]
# # Group by:

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
#group by tranmission, name, year, fuel and price
by_transmission = df.groupby(by= ["transmission", "name", "year", "selling_price", "fuel"])["name"].count().reset_index(name="count")
by_transmission = by_transmission.set_index("transmission")
by_transmission = by_transmission.sort_values("count", ascending = False)
by_transmission
# Out:
#                                           name  year  selling_price    fuel  \
# transmission
# Manual                  Maruti Swift Dzire VDI  2017         600000  Diesel
# Manual          Renault Duster 85PS Diesel RxL  2013         450000  Diesel
# Manual                     Maruti SX4 Vxi BSIV  2012         225000  Petrol
# Automatic              Audi A4 3.0 TDI Quattro  2013        1580000  Diesel
# Manual         Maruti S-Cross Zeta DDiS 200 SH  2015         750000  Diesel
# ...                                        ...   ...            ...     ...
# Manual             Hyundai Xcent 1.1 CRDi Base  2016         515000  Diesel
# Manual             Hyundai Xcent 1.1 CRDi Base  2017         300000  Diesel
# Manual                Hyundai Xcent 1.1 CRDi S  2016         270000  Diesel
# Manual               Hyundai Xcent 1.1 CRDi SX  2016         430000  Diesel
# Manual        Volkswagen Vento Petrol Highline  2011         400000  Petrol
#
#               count
# transmission
# ...

# %%
#grouping by fuel, name and tranmission
by_fuel = df.groupby(by = ["fuel", "name", "transmission"])["name"].count().reset_index(name="count")
by_fuel = by_fuel.set_index("fuel")
by_fuel = by_fuel.sort_values("count", ascending = False)
by_fuel
# Out:
#                                       name transmission  count
# fuel
# Diesel              Maruti Swift Dzire VDI       Manual     69
# Petrol                 Maruti Alto 800 LXI       Manual     59
# Petrol                     Maruti Alto LXi       Manual     47
# Petrol                      Maruti Alto LX       Manual     35
# Petrol                Hyundai EON Era Plus       Manual     35
# ...                                    ...          ...    ...
# Diesel      Tata Tiago 2019-2020 XE Diesel       Manual      1
# Diesel                     Tata Venture EX       Manual      1
# Diesel   Tata Winger Deluxe - Hi Roof (AC)       Manual      1
# Diesel                Tata Xenon XT EX 4X4       Manual      1
# Diesel  Toyota Innova Crysta 2.4 G MT BSIV       Manual      1
#
# [1491 rows x 3 columns]

# %%
#grouping by price, name, year and seller_type
by_price = df.groupby(by = ["name","year","selling_price", "seller_type", "fuel"])["year"].count().reset_index(name="count")
by_price = by_price.sort_values("selling_price", ascending = False)
by_price = by_price.set_index("selling_price")
by_price
# Out:
#                                                             name  year  \
# selling_price
# 8900000                 Audi RS7 2015-2019 Sportback Performance  2016
# 8150000        Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017
# 5500000                  Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016
# 4950000                                  BMW X5 xDrive 30d xLine  2019
# 4800000                            BMW 5 Series 520d Luxury Line  2019
# ...                                                          ...   ...
# 35000                                         Tata Nano Std BSII  2009
# 35000                                           OpelCorsa 1.4 GL  2002
# 30000                                              Maruti 800 EX  2004
# 22000                                          Ford Ikon 1.4 ZXi  2000
# 20000                                      Ford Ikon 1.6 ZXI NXt  2005
#
#               seller_type    fuel  count
# selling_price
# 8900000            Dealer  Petrol      1
# ...

# %%
by_km_driven = df.groupby(by = ["name",  "km_driven", "selling_price", "fuel"])["name"].count().reset_index(name= "count")
by_km_driven = by_km_driven.set_index("km_driven")
by_km_driven = by_km_driven.sort_values("km_driven", ascending = False)
by_km_driven
# Out:
#                                                     name  selling_price  \
# km_driven
# 806599                            Maruti Swift VXI BSIII         250000
# 560000                 Maruti SX4 S Cross DDiS 320 Delta         665000
# 400000       Toyota Innova 2.5 G (Diesel) 7 Seater BS IV         400000
# 350000     Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII         280000
# 350000               Toyota Innova 2.5 V Diesel 8-seater         350000
# ...                                                  ...            ...
# 1000                                     Tata Harrier XE         426000
# 101                    Ford Ecosport 1.5 Diesel Titanium        1000000
# 101                                   Ford Figo Titanium         635000
# 101                       Ford Freestyle Titanium Diesel         784000
# 1                                     Mahindra Quanto C6         250000
#
#              fuel  count
# km_driven
# 806599     Petrol      1
# 560000     Diesel      2
# ...

# %%
#Queries
transmission_query  = by_transmission.query("`count`> 10")
transmission_query
# Out:
#                                                   name  year  selling_price  \
# transmission
# Manual                          Maruti Swift Dzire VDI  2017         600000
# Manual                  Renault Duster 85PS Diesel RxL  2013         450000
# Manual                             Maruti SX4 Vxi BSIV  2012         225000
# Automatic                      Audi A4 3.0 TDI Quattro  2013        1580000
# Manual                 Maruti S-Cross Zeta DDiS 200 SH  2015         750000
# Manual                       Hyundai Creta 1.6 CRDi SX  2016         535000
# Manual                           Maruti Swift ZXI BSIV  2016         670000
# Manual                               Hyundai Santro GS  2005          80000
# Manual                       Hyundai Verna 1.6 VTVT SX  2015         760000
# Automatic         Hyundai Grand i10 1.2 Kappa Magna AT  2017         550000
# Manual                        Chevrolet Beat LT Option  2016         239000
# ...

# %%
#query of fuel group with more than 30 cars
fuel_query = by_fuel.query("`count` > 30")
fuel_query
# Out:
#                           name transmission  count
# fuel
# Diesel  Maruti Swift Dzire VDI       Manual     69
# Petrol     Maruti Alto 800 LXI       Manual     59
# Petrol         Maruti Alto LXi       Manual     47
# Petrol          Maruti Alto LX       Manual     35
# Petrol    Hyundai EON Era Plus       Manual     35

# %%
#query of cars above  500000
price_query = by_price.query("`selling_price`>500000")
price_query
# Out:
#                                                name  year       seller_type  \
# selling_price
# 750000              Maruti S-Cross Zeta DDiS 200 SH  2015  Trustmark Dealer
# 670000                        Maruti Swift ZXI BSIV  2016  Trustmark Dealer
# 550000         Hyundai Grand i10 1.2 Kappa Magna AT  2017            Dealer
# 1580000                     Audi A4 3.0 TDI Quattro  2013            Dealer
# 535000                    Hyundai Creta 1.6 CRDi SX  2016        Individual
# ...                                             ...   ...               ...
# 550000             Hyundai i20 Asta Option 1.4 CRDi  2016        Individual
# 580000             Hyundai i20 Asta Option 1.4 CRDi  2016        Individual
# 650000             Hyundai i20 Asta Option 1.4 CRDi  2016        Individual
# 750000             Hyundai i20 Asta Option 1.4 CRDi  2016        Individual
# 2000000                   Volvo XC60 D5 Inscription  2014        Individual
#
#                  fuel  count
# ...

# %%
#top ten expensive vehicles
by_price.head(10)
# Out:
#                                                             name  year  \
# selling_price
# 8900000                 Audi RS7 2015-2019 Sportback Performance  2016
# 8150000        Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017
# 5500000                  Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016
# 4950000                                  BMW X5 xDrive 30d xLine  2019
# 4800000                            BMW 5 Series 520d Luxury Line  2019
# 4800000                            BMW 5 Series 520d Luxury Line  2018
# 4700000                                        Audi A5 Sportback  2020
# 4500000               Mercedes-Benz E-Class Exclusive E 200 BSIV  2018
# 4500000                          Volvo XC 90 D5 Inscription BSIV  2017
# 4400000           Mercedes-Benz GL-Class 350 CDI Blue Efficiency  2014
#
#               seller_type    fuel  count
# selling_price
# 8900000            Dealer  Petrol      1
# 8150000            Dealer  Diesel      1
# ...

# %% [markdown]
# # Visualization

# %%
sns.barplot(x = transmission_query.reset_index()["name"], y = transmission_query.reset_index()["count"],
            hue = transmission_query.reset_index()["transmission"])
plt.xticks(rotation=90)
plt.legend(ncol=10, loc="upper center")
plt.title("name vs count")
# Out:
# Text(0.5, 1.0, 'name vs count')

# %%
sns.barplot(x = fuel_query.reset_index()["fuel"], y = fuel_query.reset_index()["count"])
plt.title("fuel vs count")
# Out:
# Text(0.5, 1.0, 'fuel vs count')

# %%
sns.barplot(x = price_query.reset_index()["seller_type"], y = price_query.reset_index()["selling_price"], hue = price_query.reset_index()["fuel"])
plt.xticks(rotation = 65)
plt.title("seller type vs seller  price")
# Out:
# Text(0.5, 1.0, 'seller type vs seller  price')

# %%
fuel_query.plot.pie(y="count")
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.distplot(df["selling_price"])
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
plt.hist(df["selling_price"], bins = 5)
# Out:
# (array([4.219e+03, 8.200e+01, 3.600e+01, 1.000e+00, 2.000e+00]),
#  array([  20000., 1796000., 3572000., 5348000., 7124000., 8900000.]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(y  = df["selling_price"])
# Out:
# <AxesSubplot:ylabel='selling_price'>
